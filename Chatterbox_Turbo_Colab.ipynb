# %% [markdown]
# <a href="https://colab.research.google.com/github/AkashYadavCoding/Aws-Project/blob/main/Chatterbox_Turbo_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 🏷️ **Credits & License**
#
# * 🔗 [Chatterbox-Turbo GitHub Repository](https://github.com/resemble-ai/chatterbox)
# * 🤗 [Chatterbox-Turbo on Hugging Face](https://huggingface.co/ResembleAI/chatterbox-turbo)
# * 📄 **License**: Provided under the [MIT License](https://github.com/resemble-ai/chatterbox/blob/master/LICENSE)
# * 🤗 [Chatterbox-Turbo Gradio UI code](https://huggingface.co/spaces/ResembleAI/chatterbox-turbo-demo)
#
#
#
# ### ⚠️ **Usage Disclaimer**
#
# Use of this voice cloning model is subject to strict ethical and legal standards. By using this tool, you agree **not to** engage in any of the following prohibited activities:
#
# * **Fraud or Deception**: Using cloned voices to create misleading or fraudulent content.
# * **Impersonation**: Replicating someone’s voice without their explicit permission, especially for malicious, harmful, or deceptive purposes.
# * **Illegal Activities**: Employing the model in any manner that violates local, national, or international laws and regulations.
# * **Harmful Content Generation**: Creating offensive, defamatory, or unethical material, including content that spreads misinformation or causes harm.
#
# > ⚖️ **Legal Responsibility**
# > The developers of this tool disclaim all liability for misuse. **Users bear full responsibility** for ensuring that their usage complies with all applicable laws, regulations, and ethical guidelines.

# %%
#@title Install Chatterbox Turbo
# %cd /content/
# !wget https://raw.githubusercontent.com/NeuralFalconYT/Chatterbox-Turbo-Colab/refs/heads/main/app.py
# !git clone https://github.com/resemble-ai/chatterbox.git

# Delete colab bug files
# !rm -f /content/chatterbox/src/chatterbox/__init__.py
# !rm -f /content/chatterbox/src/chatterbox/tts_turbo.py
# Download your patched file into the correct place
# !wget -O /content/chatterbox/src/chatterbox/__init__.py \
https://raw.githubusercontent.com/NeuralFalconYT/Chatterbox-Turbo-Colab/refs/heads/main/__init__.py

# !wget -O /content/chatterbox/src/chatterbox/hf_downloader.py \
 https://raw.githubusercontent.com/NeuralFalconYT/Useful-Function/refs/heads/main/hf_downloader.py

# !wget -O /content/chatterbox/src/chatterbox/tts_turbo.py \
 https://raw.githubusercontent.com/NeuralFalconYT/Chatterbox-Turbo-Colab/refs/heads/main/tts_turbo.py

# !pip install numpy~=1.26.0
# !pip install resampy==0.4.3
# !pip install librosa==0.11.0
# !pip install s3tokenizer==0.2.0
# !pip install torch==2.6.0
# !pip install torchaudio==2.6.0
# !pip install torchcodec==0.8.1
# !pip install transformers==4.46.3
# !pip install diffusers==0.29.0
# !pip install resemble-perth==1.0.1
# !pip install omegaconf==2.3.0
# !pip install conformer==0.3.2
# !pip install safetensors==0.5.3
# !pip install sentencex==0.6.1
# !pip install pydub==0.25.1
# !pip install soundfile==0.13.1
# !pip install pyloudnorm==0.1.1

from IPython.display import Audio,display
from IPython.display import clear_output
import time
clear_output()

display(Audio("https://raw.githubusercontent.com/NeuralFalconYT/Useful-Function/refs/heads/main/audio/warning.mp3", autoplay=True))
time.sleep(6)
clear_output()
time.sleep(5)
import os
os.kill(os.getpid(), 9)
# Out:
# /content
# --2026-07-25 05:41:45--  https://raw.githubusercontent.com/NeuralFalconYT/Chatterbox-Turbo-Colab/refs/heads/main/app.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12903 (13K) [text/plain]
# Saving to: ‘app.py.1’
#
# app.py.1            100%[===================>]  12.60K  --.-KB/s    in 0s
#
# 2026-07-25 05:41:45 (90.2 MB/s) - ‘app.py.1’ saved [12903/12903]
#
# fatal: destination path 'chatterbox' already exists and is not an empty directory.
# --2026-07-25 05:41:46--  https://raw.githubusercontent.com/NeuralFalconYT/Chatterbox-Turbo-Colab/refs/heads/main/__init__.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.110.133, ...
# ...

# %% [markdown]
# Don't panic if you see this ![image.png](data:image/png;base64,...) red error cell, that just means Colab automatically restarted the kernel. Now, simply run the next cell.

# %%
#@title Prevent Colab Sleep (If You Are Running Colab on a Smartphone)
from IPython.display import Audio,display
display(Audio("https://raw.githubusercontent.com/KoboldAI/KoboldAI-Client/main/colab/silence.m4a", autoplay=True))

# %%
#@title Run Chatterbox Turbo
# %cd /content/
# !python app.py --share --debug
